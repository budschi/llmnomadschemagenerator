# %%
# !pip install statsmodels
# !pip install structlog

# %%
# !pip install nomad-lab[infrastructure]

# %%
# !pip install git+https://github.com/FAIRmat-NFDI/nomad-material-processing@main
# !pip install git+https://github.com/FAIRmat-NFDI/nomad-measurements.git@main # main branch
# !pip install git+https://github.com/FAIRmat-NFDI/nomad-analysis.git@main # develop branch
# !pip install git+https://github.com/FAIRmat-NFDI/AreaA-data_modeling_and_schemas.git@main#subdirectory=IKZ_plugin
# !pip install git+https://github.com/FAIRmat-NFDI/AreaA-data_modeling_and_schemas.git@main#subdirectory=LayTec_EpiTT_plugin
# !pip install git+https://github.com/FAIRmat-NFDI/AreaA-data_modeling_and_schemas.git@main#subdirectory=Lakeshore_plugin

# %%
import yaml
import json
import statsmodels
from nomad.metainfo import Package
from nomad.datamodel import EntryArchive
from nomad.datamodel.metainfo.basesections import *
from nomad_material_processing import *
from nomad_material_processing.vapor_deposition import *
from nomad_material_processing.vapor_deposition.cvd import *
from nomad_material_processing.vapor_deposition.pvd import *
from nomad_material_processing.vapor_deposition.pvd import *
from nomad_material_processing.vapor_deposition.pvd.pld import *
from nomad_material_processing.vapor_deposition.pvd.sputtering import *
from nomad_material_processing.vapor_deposition.pvd.thermal import *
from nomad_material_processing.combinatorial import *
from nomad_material_processing.crystal_growth import *
from nomad_material_processing.epitaxy import *
from ikz_plugin import *
from ikz_plugin.movpe import *
from ikz_plugin.characterization import *

# %%
full_list_of_classes = [
            BaseSection.m_def,
            Entity.m_def,
            ActivityStep.m_def,
            Activity.m_def,
            SectionReference.m_def,
            EntityReference.m_def,
            ExperimentStep.m_def,
            Experiment.m_def,
            Collection.m_def,
            ElementalComposition.m_def,
            System.m_def,
            Instrument.m_def,
            InstrumentReference.m_def,
            Component.m_def,
            SystemComponent.m_def,
            PureSubstanceSection.m_def,
            PureSubstanceComponent.m_def,
            CompositeSystem.m_def,
            CompositeSystemReference.m_def,
            ProcessStep.m_def,
            Process.m_def,
            ActivityResult.m_def,
            AnalysisResult.m_def,
            Analysis.m_def,
            SynthesisMethod.m_def,
            MeasurementResult.m_def,
            Measurement.m_def,
            PureSubstance.m_def,
            PubChemPureSubstanceSection.m_def,
            CASExperimentalProperty.m_def,
            CASPropertyCitation.m_def,
            CASPureSubstanceSection.m_def,
            ReadableIdentifiers.m_def,
            PublicationReference.m_def,
            HDF5Normalizer.m_def,
            Geometry.m_def,
            Parallelepiped.m_def,
            Miscut.m_def,
            Dopant.m_def,
            CrystalProperties.m_def,
            SubstrateCrystalProperties.m_def,
            Substrate.m_def,
            CrystallineSubstrate.m_def,
            ThinFilm.m_def,
            #ThinFilmReference.m_def,
            ThinFilmStack.m_def,
            SampleDeposition.m_def,
            TimeSeries.m_def,
            MolarFlowRate.m_def,
            EvaporationSource.m_def,
            VaporDepositionSource.m_def,
            GrowthRate.m_def,
            Temperature.m_def,
            SampleParameters.m_def,
            Pressure.m_def,
            VolumetricFlowRate.m_def,
            GasFlow.m_def,
            SubstrateHeater.m_def,
            ChamberEnvironment.m_def,
            VaporDepositionStep.m_def,
            VaporDeposition.m_def,
            Rotation.m_def,
            PartialVaporPressure.m_def,
            BubblerMolarFlowRate.m_def,
            CVDEvaporationSource.m_def,
            BubblerEvaporator.m_def,
            FlashEvaporator.m_def,
            GasSupply.m_def,
            GasLine.m_def,
            GasCylinder.m_def,
            CVDSource.m_def,
            SourcePower.m_def,
            PVDEvaporationSource.m_def,
            ImpingingFlux.m_def,
            PVDSource.m_def,
            PVDSampleParameters.m_def,
            PVDStep.m_def,
            PhysicalVaporDeposition.m_def,
            BubblerPrecursor.m_def,
            Cylinder.m_def,
            MiscutMovpe.m_def,
            SubstrateCrystalPropertiesMovpe.m_def,
            SubstrateMovpe.m_def,
            ThinFilmMovpe.m_def,
            ThinFilmStackMovpe.m_def,
            #ThinFilmStackMovpeReference.m_def,
            SystemComponentIKZ.m_def,
            PrecursorsPreparationIKZ.m_def,
            #InSituMonitoringReference.m_def,
            #PrecursorsPreparationIKZReference.m_def,
            #HallMeasurementReference.m_def,
            #SubstrateMovpeReference.m_def,
            #AFMmeasurementReference.m_def,
            #LiMimeasurementReference.m_def,
            SubstrateInventory.m_def,
            CharacterizationMovpe.m_def,
            ShaftTemperature.m_def,
            FilamentTemperature.m_def,
            LayTecTemperature.m_def,
            BubblerSourceIKZ.m_def,
            FlashSourceIKZ.m_def,
            GasSourceIKZ.m_def,
            GasFlowMovpe.m_def,
            ChamberEnvironmentMovpe.m_def,
            SampleParametersMovpe.m_def,
            GrowthStepMovpeIKZ.m_def,
            GrowthStepMovpe1IKZ.m_def,
            GrowthStepMovpe2IKZ.m_def,
            GrowthMovpeIKZ.m_def,
            #GrowthMovpeIKZReference.m_def,
            GrowthMovpe1IKZConstantParameters.m_def,
            #GrowthMovpe1IKZConstantParametersReference.m_def,
            ExperimentMovpeIKZ.m_def,
            AFMresults.m_def,
            AFMmeasurement.m_def,
            LiMiresults.m_def,
            LightMicroscope.m_def,
            SubstratePreparationStep.m_def,
            #SubstratePreparationStepReference.m_def,
            SolutionPreparationStep.m_def,
            ComponentConcentration.m_def,
            SolutionProperties.m_def,
            SolutionStorage.m_def,
            LiquidComponent.m_def,
            Solution.m_def,
            SolutionReference.m_def,
            QuantifyMaterial.m_def,
            QuantifySolidMaterial.m_def,
            QuantifyLiquidMaterial.m_def,
            MixMaterial.m_def,
            SolutionPreparationIKZ.m_def,
            EtchingStep.m_def,
            Etching.m_def,
            Annealing.m_def,
            SubstratePreparationIKZ.m_def,
            SampleCutIKZ.m_def,
        ]
short_list_of_classes = [
            BaseSection.m_def,
            Entity.m_def,
            ActivityStep.m_def,
            Activity.m_def,
            SectionReference.m_def,
            EntityReference.m_def,
            ExperimentStep.m_def,
            Experiment.m_def,
            Collection.m_def,
            ElementalComposition.m_def,
            System.m_def,
            Component.m_def,
            SystemComponent.m_def,
            PureSubstanceSection.m_def,
            PureSubstanceComponent.m_def,
            CompositeSystem.m_def,
            CompositeSystemReference.m_def,
            ProcessStep.m_def,
            Process.m_def,
            ActivityResult.m_def,
            AnalysisResult.m_def,
            Analysis.m_def,
            SynthesisMethod.m_def,
            MeasurementResult.m_def,
            Measurement.m_def,
            PureSubstance.m_def,
            PubChemPureSubstanceSection.m_def,
            Geometry.m_def,
            Parallelepiped.m_def,
            CrystalProperties.m_def,
            SubstrateCrystalProperties.m_def,
            Substrate.m_def,
            CrystallineSubstrate.m_def,
            ThinFilm.m_def,
            ThinFilmStack.m_def,
            SampleDeposition.m_def,
            TimeSeries.m_def,
            MolarFlowRate.m_def,
            EvaporationSource.m_def,
            GrowthRate.m_def,
            Temperature.m_def,
            Pressure.m_def,
            VolumetricFlowRate.m_def,
            GasFlow.m_def,
            SubstrateHeater.m_def,
            ChamberEnvironment.m_def,
            VaporDepositionStep.m_def,
            VaporDeposition.m_def,
            Rotation.m_def,
            PartialVaporPressure.m_def,
            BubblerMolarFlowRate.m_def,
            CVDEvaporationSource.m_def,
            BubblerEvaporator.m_def,
            FlashEvaporator.m_def,
            GasSupply.m_def,
            GasLine.m_def,
            GasCylinder.m_def,
            CVDSource.m_def,
            SourcePower.m_def,
            BubblerPrecursor.m_def,
            Cylinder.m_def,
            MiscutMovpe.m_def,
            SubstrateCrystalPropertiesMovpe.m_def,
            SubstrateMovpe.m_def,
            ThinFilmMovpe.m_def,
            ThinFilmStackMovpe.m_def,
            SystemComponentIKZ.m_def,
            PrecursorsPreparationIKZ.m_def,
            CharacterizationMovpe.m_def,
            ShaftTemperature.m_def,
            FilamentTemperature.m_def,
            LayTecTemperature.m_def,
            BubblerSourceIKZ.m_def,
            FlashSourceIKZ.m_def,
            GasSourceIKZ.m_def,
            GasFlowMovpe.m_def,
            ChamberEnvironmentMovpe.m_def,
            SampleParametersMovpe.m_def,
            GrowthStepMovpeIKZ.m_def,
            GrowthStepMovpe1IKZ.m_def,
            GrowthStepMovpe2IKZ.m_def,
            GrowthMovpeIKZ.m_def,
            GrowthMovpe1IKZConstantParameters.m_def,
            ExperimentMovpeIKZ.m_def,
            AFMresults.m_def,
            AFMmeasurement.m_def,
            LiMiresults.m_def,
            LightMicroscope.m_def,
        ]

# %%
full_list_wo_refs = EntryArchive(
    definitions=Package(
        section_definitions=full_list_of_classes
    )
).m_to_dict(with_out_meta=True, 
            with_root_def=True,
            resolve_references=False,
           )

# %%
with open("full_list_wo_refs.schema.archive.yaml", 'wt') as outfile:  
    outfile.write(yaml.dump(full_list_wo_refs, indent=2).replace('!!python/object/apply:nomad.datamodel.metainfo.annotations.ELNComponentEnum', '').replace('!!python/object/apply:nomad.datamodel.metainfo.annotations.BrowserAdaptors','').replace('!!python/object/apply:nomad.datamodel.metainfo.annotations.TabularMode','').replace('!!python/object/apply:nomad.datamodel.metainfo.annotations.TabularFileModeEnum','').replace('eln', 'a_eln'))

# %%
short_list_wo_refs = EntryArchive(
    definitions=Package(
        section_definitions=short_list_of_classes
    )
).m_to_dict(with_out_meta=False, 
            with_root_def=True,
            resolve_references=False,
           )

# %%
with open("short_list_wo_refs.schema.archive.yaml", 'wt') as outfile:  
    outfile.write(yaml.dump(short_list_wo_refs, indent=2).replace('!!python/object/apply:nomad.datamodel.metainfo.annotations.ELNComponentEnum', '').replace('!!python/object/apply:nomad.datamodel.metainfo.annotations.BrowserAdaptors','').replace('!!python/object/apply:nomad.datamodel.metainfo.annotations.TabularMode','').replace('!!python/object/apply:nomad.datamodel.metainfo.annotations.TabularFileModeEnum','').replace('eln', 'a_eln'))

# %%
full_list_w_refs = EntryArchive(
    definitions=Package(
        section_definitions=full_list_of_classes
    )
).m_to_dict(with_out_meta=True, 
            with_root_def=True,
            resolve_references=True,
           )

# %%
with open("full_list_w_refs.schema.archive.yaml", 'wt') as outfile:  
    outfile.write(yaml.dump(full_list_w_refs, indent=2).replace('!!python/object/apply:nomad.datamodel.metainfo.annotations.ELNComponentEnum', '').replace('!!python/object/apply:nomad.datamodel.metainfo.annotations.BrowserAdaptors','').replace('!!python/object/apply:nomad.datamodel.metainfo.annotations.TabularMode','').replace('!!python/object/apply:nomad.datamodel.metainfo.annotations.TabularFileModeEnum','').replace('eln', 'a_eln'))

# %%
short_list_w_refs = EntryArchive(
    definitions=Package(
        section_definitions=short_list_of_classes
    )
).m_to_dict(with_out_meta=True, 
            with_root_def=True,
            resolve_references=True,
           )

# %%
with open("short_list_w_refs.schema.archive.yaml", 'wt') as outfile:  
    outfile.write(yaml.dump(short_list_w_refs, indent=2).replace('!!python/object/apply:nomad.datamodel.metainfo.annotations.ELNComponentEnum', '').replace('!!python/object/apply:nomad.datamodel.metainfo.annotations.BrowserAdaptors','').replace('!!python/object/apply:nomad.datamodel.metainfo.annotations.TabularMode','').replace('!!python/object/apply:nomad.datamodel.metainfo.annotations.TabularFileModeEnum','').replace('eln', 'a_eln'))
